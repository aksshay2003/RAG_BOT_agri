# %% [markdown]
# **RAG**

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-02a7340e419e> in <cell line: 1>()
# ----> 1 from langchain.text_splitter import RecursiveCharacterTextSplitter
#
# ModuleNotFoundError: No module named 'langchain'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# **START OF THE PROJECT**

# %%
# !pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 975.5/975.5 kB 10.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 332.8/332.8 kB 16.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.4/127.4 kB 13.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.0/145.0 kB 13.7 MB/s eta 0:00:00
# ...

# %%
# !pip install langchain_community
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 14.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 7.3 MB/s eta 0:00:00
# ...

# %%
# !pip install pypdf
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 8.4 MB/s eta 0:00:00
# ...

# %%
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
pdf_loader = PyPDFLoader("Operating_System_Objectives_1710239226940.pdf")
pages = pdf_loader.load_and_split()
print(pages[0].page_content)
# Out:
# A computer system is divided into two categories: Hardware and Software.
# Hardware refers to the physical and visible components of the system such as a monitor, CPU,
# keyboard and mouse.
# Software , on the other hand, refers to a set of instructions which enable the hardware to perform
# a specific set of tasks.
#
#
#
# Types of Computer Software
#  System  Software
#  Application  Software
# System  Software:  System Software is a component of Computer Software that directly operates
# with Computer Hardware which has the work to control the Computer’s Internal Functioning and
# also takes responsibility for controlling Hardware Devices suc h as Printers, Storage Devices, etc.
# Types of System Software include Operating systems, Language processors, and Device Drivers.
# Application  Software:  Application Software are the software that works the basic operations of
# the computer. It performs a specific task for users. Application Software basically includes Word
# ...

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=100, chunk_overlap=80)
context = "\n\n".join(str(p.page_content) for p in pages)
chunks = text_splitter.split_text(context)

# %%
print(chunks)
# Out:
# ['A computer system is divided into two categories: Hardware and Software.', 'Hardware refers to the physical and visible components of the system such as a monitor, CPU,', 'keyboard and mouse.', 'Software , on the other hand, refers to a set of instructions which enable the hardware to perform', 'a specific set of tasks.  \n \n \n \nTypes of Computer Software  \n\uf0b7 System  Software', 'Types of Computer Software  \n\uf0b7 System  Software  \n\uf0b7 Application  Software', 'System  Software:  System Software is a component of Computer Software that directly operates', 'with Computer Hardware which has the work to control the Computer’s Internal Functioning and', 'also takes responsibility for controlling Hardware Devices suc h as Printers, Storage Devices, etc.', 'for controlling Hardware Devices suc h as Printers, Storage Devices, etc.', 'Types of System Software include Operating systems, Language processors, and Device Drivers.', 'Application  Software:  Application Software ar
# ...

# %%
# !pip install sentence_transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 6.7 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
pip install torch

# %%
 from sentence_transformers import SentenceTransformer
from sentence_transformers.util import cos_sim

# sentences = ['That is a happy person', 'That is a very happy person']

model = SentenceTransformer('thenlper/gte-small')
# embeddings = model.encode(sentences)
# # print(cos_sim(embeddings[0], embeddings[1]))
# print(embeddings)
# Out:
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/68.1k [00:00<?, ?B/s]
# ...

# %%
from transformers import AutoTokenizer

# %%
# !pip install tqdm

# %%
 from tqdm import tqdm
l=[]
for docs in tqdm(chunks):
  l.append(len(model.encode(docs)))


len(l)#word embeddings
# Out:
# 100%|██████████| 61/61 [00:05<00:00, 11.41it/s]
# 61

# %%
l[:5]
# Out:
# [384, 384, 384, 384, 384]

# %%
# #training again with new chunk_size
# from langchain.text_splitter import RecursiveCharacterTextSplitter
# splitter = RecursiveCharacterTextSplitter(chunk_size=540, chunk_overlap=50)


# # Split the text into chunks
# newchunks = splitter.split_text(Page)
# print(type(newchunks))
# print(len(newchunks))
# i=0
# for chunk in newchunks:
#   print(i,"chunk----->:",chunk)
#   i=i+1

# %%
# #removing duplicate chunks in case if they are present
# unique_chunks=[]
# # for chunk in newchunks:
#   if chunk not in unique_chunks:
#     unique_chunks.append(chunk)
# print(unique_chunks)
# i=0
# for chunks in unique_chunks:
#   print("chunk:",i,"-------->",chunks)
#   i=i+1

# %% [markdown]
# model is for encoding the chunks

# %%
from tqdm import tqdm
length_list=[]
vector_list=[]
for docs in tqdm(chunks):
  # length_list.append(len(model.encode(docs)))
  vector_list.append(model.encode(docs))

print(len(length_list))#word embeddings
print(length_list)
# Out:
# 100%|██████████| 61/61 [00:00<00:00, 98.15it/s]
# 0
# []

# %%
len(vector_list)
# Out:
# 61

# %%
vector_list[0]
# Out:
# array([-3.40593755e-02, -9.04113892e-03,  4.13875319e-02, -6.52922541e-02,
#         9.80898552e-03, -4.14383644e-03,  5.03332652e-02,  3.13801020e-02,
#         2.49497350e-02, -2.07985211e-02, -4.64517158e-03, -5.08965664e-02,
#         6.42041340e-02, -1.25958584e-02,  3.04390453e-02, -2.77839843e-02,
#         3.73209566e-02,  2.64191348e-02, -6.83197286e-03,  2.64169946e-02,
#         5.47159426e-02, -4.58868779e-02, -5.00326529e-02, -6.85566515e-02,
#        -2.55100746e-02,  3.93995158e-02, -4.77441251e-02, -2.70244554e-02,
#        -5.07345907e-02, -1.41236559e-01, -2.58319527e-02, -1.88728422e-02,
#         4.67134975e-02, -4.17475738e-02, -6.31017657e-03, -5.34193777e-02,
#         8.99756048e-03,  7.80381216e-03, -7.92034268e-02,  4.21911925e-02,
#        -2.86467429e-02, -7.43235275e-03, -1.30561851e-02, -4.69285734e-02,
#         7.29130767e-03, -5.32721281e-02, -4.41761836e-02, -1.97884701e-02,
# ...

# %%
len(vector_list[0])
# Out:
# 384

# %% [markdown]
# using Huggingface completely locally

# %%
documents = [{'page_content': chunk} for chunk in unique_chunks]
print(documents)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-05ff122fc0c6> in <cell line: 1>()
# ----> 1 documents = [{'page_content': chunk} for chunk in unique_chunks]
#       2 print(documents)
#
# NameError: name 'unique_chunks' is not defined

# %% [markdown]
# not used except library

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings
embedding_model = HuggingFaceEmbeddings(
    model_name='thenlper/gte-small',
    multi_process=True,
    model_kwargs={'device': 'cpu'},
    encode_kwargs={'normalize_embeddings': True}
    )
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 0.3.0. An updated version of the class exists in the langchain-huggingface package and should be used instead. To use it run `pip install -U langchain-huggingface` and import as `from langchain_huggingface import HuggingFaceEmbeddings`.
#   warn_deprecated(

# %% [markdown]
# tokeniser

# %%
modelname='thenlper/gte-small'
from transformers import pipeline,AutoTokenizer
tokenizer=AutoTokenizer.from_pretrained(modelname)

# %%
# !pip install faiss-cpu
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.0/27.0 MB 8.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# this is similar to final one(langchain_community.vectorstores) document

# %% [markdown]
# HuggingFaceEmbeddings

# %%
#vector_database using FAISS(Facebook AI Similarity Search)
# modelname='thenlper/gte-small',
from langchain_community.vectorstores import FAISS
from langchain_community.vectorstores.utils import DistanceStrategy
embeddings = HuggingFaceEmbeddings()
# embeddings = embedding_model.embed_documents(unique_chunks)
vector_database=FAISS.from_texts(unique_chunks,embeddings,distance_strategy=DistanceStrategy.COSINE)
print(vector_database)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-4c1c653ced54> in <cell line: 7>()
#       5 embeddings = HuggingFaceEmbeddings()
# ...

# %% [markdown]
# final one

# %%
from langchain_community.vectorstores import FAISS
from langchain_community.vectorstores.utils import DistanceStrategy  #for similarity search
vector_database=FAISS.from_texts(chunks,embedding_model,distance_strategy=DistanceStrategy.COSINE)

# %% [markdown]
# resuming from final code

# %% [markdown]
# blackgram wheat recorded higher net returns
# (Rs.104950/ha) and B:C ratio (2.80) .

# %%
print(retrieved_docs[0].page_content)

# %% [markdown]
# as we can see we retrieved the top document of our question which contains the answer

# %% [markdown]
# '''ICAR-CRIDA Annual Report 2022
# 83Maize sown in between alleys
# • In subhumid Inseptisols at Chianki, in aonla and
# kharif  crops based agri-horti system, aonla + black
# gram gave significantly higher aonla equivalent yield
# (AEY) (8.88 t/ha) followed by aonla + groundnut
# (8.72 t/ha) whereas, in sole crop aonla gave (8.2 t/
# ha). Similarly, maximum net returns (Rs.183100/
# ha) and RWUE (9.74 kg/ha-mm) were recorded
# in aonla + black system. Whereas,  B:C ratio was
# recorded higher (4.81) in aonla + groundnut system.
# • In sub-humid Inceptisols at Ballowal Saunkhri, in
# agri-horti-silvi-pasture model, Grewia optiva at 3
# m x 3m+ Setaria grass + black gram wheat system
# resulted in the highest system productivity (5029
# kg/ha) followed by guava at 6 m x 6 m + Setaria
# grass + black gram-wheat system sole. However,
# blackgram wheat recorded higher net returns
# (Rs.104950/ha) and B:C ratio (2.80) .
# • In semiarid Vertisols at Indore, horti-pasture system
# with guava, pomegranate, phalsa and drumstick and
# MP Chari, Hy. Bajra, Stylo Scabra and Stylo hamata,
# the mean higher fodder yield was obtained with
# hybrid bajra (14001 kg/ha) followed by Stylosanthes
# hamata  (12667 kg/ha), Stylosanthes scabra  (11067
# kg/ha).
# Drumstick/Phalas+ Hybrid bajra4.1.2 On-farm research
# On-farm participatory Rainfed Integrated Farming
# Systems Research
# The interventions are being implemented under seven
# modules (as per the need) viz. NRM, crop, livestock,
# perennial tree, fodder, specific/optional module
# (interventions specific to individual farmers’ needs) and
# capacity building. The results are briefed below:
# Ananthapuramu centre (Semiarid Alfisols)
# Under rainfed situation, for marginal farmer (0.8 ha)
# with crop + small ruminants based RIFS, different
# interventions implemented for improving the existing
# farming system were in-situ moisture conservation with
# conservation furrows; improved varieties of groundnut
# (K-9), pigeon pea (LRG-52) and fodder sorghum
# (SSG-998); groundnut + pigeon pea intercropping
# system (15:1); improved nutrition (RSMM @ 5 g/
# dat + licking of mineral block + sorghum/maize
# grain) and healthcare (deworming, deticking and
# vaccination against Enterotoxemia) of ramlambs.
# Different interventions resulted in higher groundnut
# equivalent yield (2237 kg), net returns (Rs 74651) and
# employment generation (282 man-days/year) compared
# to the existing farming system (1700 kg). The improved
# farming system gave additional returns of Rs 33593/
# year over the existing farming system.
# Bengaluru centre (Semiarid Alfisols)
# Under rainfed situation, for marginal farmer (0.8 ha)
# with crop + large ruminants (CB-HF cows) based RIFS,
# interventions on NRM practices (contour cultivation,
# use of bullock drawn seed drill, and mulching);
# improved varieties of groundnut (KCG-6), finger millet
# (MR-1), pigeonpea (BRG-5), field bean (HA-4) and
# fodder maize (SA Tall); intercropping systems  such as
# groundnut + pigeonpea (8:2) and pigeonpea + field bean
# (1:1); ex-situ  rainwater harvesting through excavation
# of farm pond; introduction of chilli cultivation;
# improved nutrition (green fodder, concentrates and
# mineral mixtures) and healthcare (deworming) of large
# ruminants in  marginal farmers category with 0.8 ha
# land area under crops + large ruminants (CLR) farming
# system recorded higher finger millet equivalent yield
# (7439 kg), net returns (Rs. 1,38,261) and  employment
# generation (357 man days)  as compared to  existing
# farming system (3365 kg system productivity with net
# returns of  Rs. 48,461 and employment generation of
# 296 man-days).'''

# %% [markdown]
# question 2:
# higher finger millet equivalent yield
# (7439 kg), net returns (Rs. 1,38,261)

# %% [markdown]
# chunk: 0 --------> ICAR CRIDA Annual Report 2022
#  83maize sow alley
#  subhumid inseptisol Chianki aonla
#  kharif   crop base agri horti system aonla + black
#  gram give significantly high aonla equivalent yield
#  AEY 8.88 t ha follow aonla + groundnut
#  8.72 t ha sole crop aonla give 8.2 t/
#  ha similarly maximum net return Rs.183100/
#  ha RWUE 9.74 kg ha mm record
#  aonla + black system   b c ratio
#  record high 4.81 aonla + groundnut system
#  sub humid Inceptisols Ballowal Saunkhri
#  agri horti silvi pasture model Grewia optiva 3
# chunk: 1 --------> agri horti silvi pasture model Grewia optiva 3
#  m x 3m+ Setaria grass + black gram wheat system
#  result high system productivity 5029
#  kg ha follow guava 6 m x 6 m + Setaria
#  grass + black gram wheat system sole
#  blackgram wheat record high net return
#  Rs.104950 ha b c ratio 2.80
#  semiarid vertisol Indore horti pasture system
#  guava pomegranate phalsa drumstick
#  MP Chari Hy Bajra Stylo Scabra Stylo hamata
#  mean high fodder yield obtain
#  hybrid bajra 14001 kg ha follow Stylosanthes
# chunk: 2 --------> hybrid bajra 14001 kg ha follow Stylosanthes
#  hamata   12667 kg ha Stylosanthes scabra   11067
#  kg ha
#  Drumstick Phalas+ Hybrid bajra4.1.2 farm research
#  farm participatory Rainfed Integrated Farming
#  Systems Research
#  intervention implement seven
#  module need viz NRM crop livestock
#  perennial tree fodder specific optional module
#  intervention specific individual farmer need
#  capacity building result brief
#  Ananthapuramu centre Semiarid Alfisols
#  rainfed situation marginal farmer 0.8 ha
# chunk: 3 --------> rainfed situation marginal farmer 0.8 ha
#  crop + small ruminant base RIFS different
#  intervention implement improve exist
#  farming system situ moisture conservation
#  conservation furrow improved variety groundnut
#  K-9 pigeon pea LRG-52 fodder sorghum
#  SSG-998 groundnut + pigeon pea intercropping
#  system 15:1 improve nutrition RSMM 5 g/
#  dat + lick mineral block + sorghum maize
#  grain healthcare deworming detick
#  vaccination Enterotoxemia ramlamb
#  different intervention result high groundnut
# chunk: 4 --------> different intervention result high groundnut
#  equivalent yield 2237 kg net return r 74651
#  employment generation 282 man day year compare
#  exist farming system 1700 kg improve
#  farming system give additional return r 33593/
#  year exist farming system
#  Bengaluru centre Semiarid Alfisols
#  rainfed situation marginal farmer 0.8 ha
#  crop + large ruminant CB HF cow base RIFS
#  intervention NRM practice contour cultivation
#  use bullock draw seed drill mulching
#  improve variety groundnut KCG-6 finger millet
# chunk: 5 --------> improve variety groundnut KCG-6 finger millet
#  mr-1 pigeonpea BRG-5 field bean HA-4
#  fodder maize SA Tall intercrop system
#  groundnut + pigeonpea 8:2 pigeonpea + field bean
#  1:1 ex situ   rainwater harvesting excavation
#  farm pond introduction chilli cultivation
#  improve nutrition green fodder concentrate
#  mineral mixture healthcare deworming large
#  ruminant   marginal farmer category 0.8 ha
#  land area crop + large ruminant CLR farming
#  system record high finger millet equivalent yield
# chunk: 6 --------> 7439 kg net return Rs 1,38,261   employment
#  generation 357 man day   compare   exist
#  farming system 3365 kg system productivity net
#  return   r 48,461 employment generation
#  296 man day

# %% [markdown]
# continuation

# %%
# !pip install langchain

# %% [markdown]
# continuation

# %%
prompt_chat=[
    {
        "role":"system",
        "content":"""using the information contained in the context,
        give a comprehensive answer to the question.
        Respond only to the question asked,response should be consise and relevant.
        If the answer cannot be deduced from the context, do not give an answer."""
        },
        {
            "role":"user",
            "content":"""context:
            {context}
            ---
            Now here is the question you need to answer.
            Question:{question}"""

        },


]

# %%
rag_template=tokenizer.apply_chat_template(
    prompt_chat,tokenizer=False,add_generation_prompt=True
)
print(rag_template)
# Out:
# No chat template is set for this tokenizer, falling back to a default class-level template. This is very error-prone, because models are often trained with templates different from the class default! Default chat templates are a legacy feature and will be removed in Transformers v4.43, at which point any code depending on them will stop working. We recommend setting a valid chat template before then to ensure that this model continues working without issues.
# ...

# %%
from transformers import AutoTokenizer

# Example token IDs
token_ids = [1026, 1064, 10047, 1035, 2707, 1064, 1028, 2291, 2478, 1996, 2592, 4838, 1999, 1996, 6123, 1010, 2507, 1037, 7721, 3437, 2000, 1996, 3160, 1012, 6869, 2069, 2000, 1996, 3160, 2356, 1010, 3433, 2323, 2022, 9530, 6190, 2063, 1998, 7882, 1012, 2065, 1996, 3437, 3685, 2022, 2139, 28901, 2013, 1996, 6123, 1010, 2079, 2025, 2507, 2019, 3437, 1012, 1026, 1064, 10047, 1035, 2203, 1064, 1028, 1026, 1064, 10047, 1035, 2707, 1064, 1028, 5310, 6123, 1024, 1063, 6123, 1065, 1011, 1011, 1011, 2085, 2182, 2003, 1996, 3160, 2017, 2342, 2000, 3437, 1012, 3160, 1024, 1063, 3160, 1065, 1026, 1064, 10047, 1035, 2203, 1064, 1028, 1026, 1064, 10047, 1035, 2707, 1064, 1028, 3353]

# Load a tokenizer (ensure this matches the tokenizer used for generating token_ids)
tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')

# Decode the token IDs to a string
decoded_string = tokenizer.decode(token_ids)

print(decoded_string)
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# < | im _ start | > system using the information contained in the context, give a comprehensive answer to the question. respond only to the question asked, response should be consise and relevant. if the answer cannot be deduced from the context, do not give an answer. < | im _ end | > < | im _ start | > user context : { context } - - - now here is the question you need to answer. question : { question } < | im _ end | > < | im _ start | > assistant

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
from transformers import pipeline,QuantoConfig
import torch
process_config=QuantoConfig(weights="int8")

# %%
import os

# %%
#  os.environ['HF_TOKEN'] = "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"

# %%
# modelname='thenlper/gte-small'
model=AutoModelForCausalLM.from_pretrained("google/gemma-2b-it",torch_dtype=torch.bfloat16)
tokenizer=AutoTokenizer.from_pretrained("google/gemma-2b-it")
# Out:
# config.json:   0%|          | 0.00/627 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/13.5k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/67.1M [00:00<?, ?B/s]
# `config.hidden_act` is ignored, you should use `config.hidden_activation` instead.
# Gemma's activation function will be set to `gelu_pytorch_tanh`. Please, use
# `config.hidden_activation` if you want to override this behaviour.
# See https://github.com/huggingface/transformers/pull/29402 for more details.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/34.2k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# ...

# %%
 # !pip install accelerate
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.4/309.4 kB 8.5 MB/s eta 0:00:00
# ...

# %%
Reader_llm=pipeline(
    model=model,
    tokenizer=tokenizer,
    task="text-generation",
    do_sample=True,
    temperature=0.2,
    repetition_penalty=1.1,
    return_full_text=False,
    max_new_tokens=500,


)

# %% [markdown]
# real translation

# %% [markdown]
# The geographic and demographic dimensions of rainfed
# agriculture warrant a continued priority for production

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, pipeline

# %%
model = AutoModelForSeq2SeqLM.from_pretrained("facebook/nllb-200-distilled-600M")
tokenizer = AutoTokenizer.from_pretrained("facebook/nllb-200-distilled-600M")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/846 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/564 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/4.85M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.3M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/3.55k [00:00<?, ?B/s]

# %%
pip install langdetect

# %% [markdown]
# Types of Computer Software
#  System  Software
#  Application  Software

# %%
query=input("Enter your query in your language")
# Out:
# Enter your query in your language"ICAR యొక్క పూర్తిపేరేంటి?"

# %% [markdown]
# "ICAR యొక్క పూర్తిపేరేంటి?"

# %%
from langdetect import detect, detect_langs

# %%
detected_lang=detect(query)
print(detected_lang)
# Out:
# te

# %%
#real

language_detect = {
    "af": "afr_Latn",    # Afrikaans
    "ar": "arb_Arab",    # Modern Standard Arabic
    "bg": "bul_Cyrl",    # Bulgarian
    "bn": "ben_Beng",    # Bengali
    "ca": "cat_Latn",    # Catalan
    "cs": "ces_Latn",    # Czech
    "cy": "cym_Latn",    # Welsh
    "da": "dan_Latn",    # Danish
    "de": "deu_Latn",    # German
    "el": "ell_Grek",    # Greek
    "en": "eng_Latn",    # English
    "es": "spa_Latn",    # Spanish
    "et": "est_Latn",    # Estonian
    "fa": "pes_Arab",    # Western Persian
    "fi": "fin_Latn",    # Finnish
    "fr": "fra_Latn",    # French
    "gu": "guj_Gujr",    # Gujarati
    "he": "heb_Hebr",    # Hebrew
    "hi": "hin_Deva",    # Hindi
    "hr": "hrv_Latn",    # Croatian
    "hu": "hun_Latn",    # Hungarian
    "id": "ind_Latn",    # Indonesian
    "it": "ita_Latn",    # Italian
    "ja": "jpn_Jpan",    # Japanese
    "kn": "kan_Knda",    # Kannada
    "ko": "kor_Hang",    # Korean
    "lt": "lit_Latn",    # Lithuanian
    "lv": "lvs_Latn",    # Standard Latvian
    "mk": "mkd_Cyrl",    # Macedonian
    "ml": "mal_Mlym",    # Malayalam
    "mr": "mar_Deva",    # Marathi
    "ne": "npi_Deva",    # Nepali
    "nl": "nld_Latn",    # Dutch
    "no": "nob_Latn",    # Norwegian Bokmål
    "pa": "pan_Guru",    # Eastern Panjabi
    "pl": "pol_Latn",    # Polish
    "pt": "por_Latn",    # Portuguese
    "ro": "ron_Latn",    # Romanian
    "ru": "rus_Cyrl",    # Russian
    "sk": "slk_Latn",    # Slovak
    "sl": "slv_Latn",    # Slovenian
    "so": "som_Latn",    # Somali
    "sq": "als_Latn",    # Tosk Albanian
    "sv": "swe_Latn",    # Swedish
    "sw": "swh_Latn",    # Swahili
    "ta": "tam_Taml",    # Tamil
    "te": "tel_Telu",    # Telugu
    "th": "tha_Thai",    # Thai
    "tl": "tgl_Latn",    # Tagalog
    "tr": "tur_Latn",    # Turkish
    "uk": "ukr_Cyrl",    # Ukrainian
    "ur": "urd_Arab",    # Urdu
    "vi": "vie_Latn",    # Vietnamese
    "zh-cn": "zho_Hans", # Chinese (Simplified)
    "zh-tw": "zho_Hant"  # Chinese (Traditional)
}

# %%
lang=language_detect[detected_lang]

# %%
print(lang)
# Out:
# tel_Telu

# %%
# print(src_lang_code)
# Out:
# None

# %%
translator = pipeline('translation', model=model, tokenizer=tokenizer, src_lang=lang, tgt_lang='eng_Latn', max_length = 400)

# %%
output=translator(query)
print(output)
# Out:
# [{'translation_text': 'How is it?'}]

# %%
for i in output:
  user_query=i['translation_text']

# %%
select_lang=input("select language:")
# Out:
# select language:bengali

# %%
languages = {
    "Afrikaans": "afr_Latn",   # af
    "Arabic": "arb_Arab",      # ar
    "Bulgarian": "bul_Cyrl",   # bg
    "Bengali": "ben_Beng",     # bn
    "Catalan": "cat_Latn",     # ca
    "Czech": "ces_Latn",       # cs
    "Welsh": "cym_Latn",       # cy
    "Danish": "dan_Latn",      # da
    "German": "deu_Latn",      # de
    "Greek": "ell_Grek",       # el
    "English": "eng_Latn",     # en
    "Spanish": "spa_Latn",     # es
    "Estonian": "est_Latn",    # et
    "Persian": "pes_Arab",     # fa
    "Finnish": "fin_Latn",     # fi
    "French": "fra_Latn",      # fr
    "Gujarati": "guj_Gujr",    # gu
    "Hebrew": "heb_Hebr",      # he
    "Hindi": "hin_Deva",       # hi
    "Croatian": "hrv_Latn",    # hr
    "Hungarian": "hun_Latn",   # hu
    "Indonesian": "ind_Latn",  # id
    "Italian": "ita_Latn",     # it
    "Japanese": "jpn_Jpan",    # ja
    "Kannada": "kan_Knda",     # kn
    "Korean": "kor_Hang",      # ko
    "Lithuanian": "lit_Latn",  # lt
    "Latvian": "lvs_Latn",     # lv
    "Macedonian": "mkd_Cyrl",  # mk
    "Malayalam": "mal_Mlym",   # ml
    "Marathi": "mar_Deva",     # mr
    "Nepali": "npi_Deva",      # ne
    "Dutch": "nld_Latn",       # nl
    "Norwegian": "nob_Latn",   # no
    "Punjabi": "pan_Guru",     # pa
    "Polish": "pol_Latn",      # pl
    "Portuguese": "por_Latn",  # pt
    "Romanian": "ron_Latn",    # ro
    "Russian": "rus_Cyrl",     # ru
    "Slovak": "slk_Latn",      # sk
    "Slovenian": "slv_Latn",   # sl
    "Somali": "som_Latn",      # so
    "Albanian": "als_Latn",    # sq
    "Swedish": "swe_Latn",     # sv
    "Swahili": "swh_Latn",     # sw
    "Tamil": "tam_Taml",       # ta
    "Telugu": "tel_Telu",      # te
    "Thai": "tha_Thai",        # th
    "Tagalog": "tgl_Latn",     # tl
    "Turkish": "tur_Latn",     # tr
    "Ukrainian": "ukr_Cyrl",   # uk
    "Urdu": "urd_Arab",        # ur
    "Vietnamese": "vie_Latn",  # vi
    "Chinese": "zho_Hans",  # zh-cn
    "Chinese (Traditional)": "zho_Hant"  # zh-tw
}

# %%
for key,value in languages.items():
  if key.casefold()==select_lang.casefold():
    src_lang_code=value
    break

# %%
print(src_lang_code)
# Out:
# ben_Beng

# %%
translator2 = pipeline('translation', model=model, tokenizer=tokenizer, src_lang=lang, tgt_lang=src_lang_code, max_length = 400)

# %%
output=translator2(query)
print(output)
# Out:
# [{'translation_text': 'কেমন আছেন?'}]

# %%
# Out:
# কেমন আছেন?

# %% [markdown]
# **Lnaguage Translation**

# %%
! pip install sentencepiece

# %%
from transformers import MBartForConditionalGeneration, MBart50TokenizerFast

# %%
model =  MBartForConditionalGeneration.from_pretrained("facebook/mbart-large-50-one-to-many-mmt")
# Out:
# config.json:   0%|          | 0.00/1.43k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.44G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/261 [00:00<?, ?B/s]

# %%
languages = {
    "Arabic": "ar_AR",
    "Czech": "cs_CZ",
    "German": "de_DE",
    "English": "en_XX",
    "Spanish": "es_XX",
    "Estonian": "et_EE",
    "Finnish": "fi_FI",
    "French": "fr_XX",
    "Gujarati": "gu_IN",
    "Hindi": "hi_IN",
    "Italian": "it_IT",
    "Japanese": "ja_XX",
    "Kazakh": "kk_KZ",
    "Korean": "ko_KR",
    "Lithuanian": "lt_LT",
    "Latvian": "lv_LV",
    "Burmese": "my_MM",
    "Nepali": "ne_NP",
    "Dutch": "nl_XX",
    "Romanian": "ro_RO",
    "Russian": "ru_RU",
    "Sinhala": "si_LK",
    "Turkish": "tr_TR",
    "Vietnamese": "vi_VN",
    "Chinese": "zh_CN",
    "Afrikaans": "af_ZA",
    "Azerbaijani": "az_AZ",
    "Bengali": "bn_IN",
    "Persian": "fa_IR",
    "Hebrew": "he_IL",
    "Croatian": "hr_HR",
    "Indonesian": "id_ID",
    "Georgian": "ka_GE",
    "Khmer": "km_KH",
    "Macedonian": "mk_MK",
    "Malayalam": "ml_IN",
    "Mongolian": "mn_MN",
    "Marathi": "mr_IN",
    "Polish": "pl_PL",
    "Pashto": "ps_AF",
    "Portuguese": "pt_XX",
    "Swedish": "sv_SE",
    "Swahili": "sw_KE",
    "Tamil": "ta_IN",
    "Telugu": "te_IN",
    "Thai": "th_TH",
    "Tagalog": "tl_XX",
    "Ukrainian": "uk_UA",
    "Urdu": "ur_PK",
    "Xhosa": "xh_ZA",
    "Galician": "gl_ES",
    "Slovene": "sl_SI"
}

# %%
language_input=input("Enter your language name:")
for key,value in languages.items():
  if key.casefold()==language_input.casefold():
    final_language=value
    break

# %%
tokenizer =MBart50TokenizerFast.from_pretrained("facebook/mbart-large-50-one-to-many-mmt", src_lang=language_input)

# %%
generated_tokens = model.generate(
    **model_inputs,
    forced_bos_token_id=tokenizer.lang_code_to_id["en_XX"]
)

# %%
translation = tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)

# %%
translation

# %%
# user_query="what is the full form of ICAR?"

retrieved_docs=vector_database.similarity_search(query=user_query,k=1)
print("top document")
print(retrieved_docs)
# Out:
# top document
# [Document(page_content='Types of Computer Software  \n\uf0b7 System  Software  \n\uf0b7 Application  Software')]

# %%
 retrieved_docs_text=[
    doc.page_content for doc in retrieved_docs
]

# %%
context="\nExtracted documents:\n"
context+="".join(
    [f"Document {str(i)}:::\n" + doc for i, doc in enumerate(retrieved_docs_text)]
)
print(context)
# Out:
# Extracted documents:
# Document 0:::
# Types of Computer Software
#  System  Software
#  Application  Software

# %%
 decoded_string = """
< | im _ start | > system using the information contained in the context, give a comprehensive answer to the question. respond only to the question asked, response should be concise and relevant. if the answer cannot be deduced from the context, do not give an answer. < | im _ end | >
< | im _ start | > user context : {context} - - - now here is the question you need to answer. question : {question} < | im _ end | >
< | im _ start | > assistant...
"""
final_prompt=decoded_string.format(
    question="What are the types of computer software?",context=context
)

# %%
final_prompt
# Out:
# '\n< | im _ start | > system using the information contained in the context, give a comprehensive answer to the question. respond only to the question asked, response should be concise and relevant. if the answer cannot be deduced from the context, do not give an answer. < | im _ end | >\n< | im _ start | > user context : \nExtracted documents:\nDocument 0:::\nTypes of Computer Software  \n\uf0b7 System  Software  \n\uf0b7 Application  Software - - - now here is the question you need to answer. question : what is the full form of FAO? < | im _ end | >\n< | im _ start | > assistant...\n'

# %%
answer=Reader_llm(final_prompt)[0]["generated_text"]

# %%
print(answer)
# Out:
# Extracted documents:
# Document 0:::
# Types of Computer Software
#  System  Software
#  Application  Software - - - now here is the question you need to answer. question : what is the full form of FAO?

# %%
# !pip install langchain_core
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 337.4/337.4 kB 5.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.5/127.5 kB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 4.3 MB/s eta 0:00:00
# ...

# %%
# !pip install langchain_google_genai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.9/163.9 kB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 718.3/718.3 kB 30.9 MB/s eta 0:00:00
# ...

# %%
GOOGLE_API_KEY="AIzaSyA41VD2xucRzgYkFYeej3gGAEEnqjwm138"

# %%
"Write a short description about the plant shown in the image and if you find any disease in the plant,please mention about the disease,if you dont find don't mention"
# Out:
# "Write a short description about the plant shown in the image and if you find any disease in the plant,please mention about the disease,if you dont find don't mention"

# %%
from langchain_core.messages import HumanMessage
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model="gemini-pro-vision",google_api_key=GOOGLE_API_KEY)
# Write the name of the plant shown in the image,write only the name,don't describe
# example
message = HumanMessage(
    content=[
        {
            "type": "text",
            "text": "Write a short description about the plant shown in the image and if you find any disease in the plant,please mention about the disease,if you dont find don't mention",
        },
        {"type": "image_url", "image_url": "cotton.jpeg"},
    ]
)
result=llm.invoke([message])

# %%
print(result.content)
# Out:
#  The image shows a cotton plant. Cotton is a major cash crop grown in many parts of the world. The plant is susceptible to a number of diseases, including **Fusarium wilt**, **Verticillium wilt**, and **boll rot**. These diseases can cause significant damage to the crop, leading to reduced yields and losses in quality.
#
# **Fusarium wilt** is a fungal disease that affects the roots and vascular system of the cotton plant. The fungus enters the plant through wounds in the roots or stem, and then spreads through the vascular system, causing the leaves to wilt and die. The disease can be managed by using resistant varieties of cotton, planting in well-drained soils, and avoiding wounding the plants.
#
# ...

# %%
# resultcontent=result.content

# %%
type(result)
# Out:
# langchain_core.messages.ai.AIMessage

# %%
message2 = HumanMessage(
    content=[
        {
            "type": "text",
            "text": f"write the name of the plant and write the disease name of the plant, kindly go through it's domain and find the relevent disease name of the , if the plant has no disease,then write as plant has no disease ",
        },
        {"type": "image_url", "image_url": "cottondisease1.jpeg"},
    ]
)
result2=llm.invoke([message2])

# %%
print(result2.content)
# Out:
#  The plant is a soybean.
# The disease is soybean rust.
# The causal organism is Phakopsora pachyrhizi.
# The domain is Eukaryota.

# %%
# from transformers import AutoTokenizer, AutoModelForCausalLM

# %%
model_inputs = tokenizer(result.content, return_tensors="pt")

# %%
languages_dict = {
    "Arabic": "ar_AR",
    "Czech": "cs_CZ",
    "German": "de_DE",
    "English": "en_XX",
    "Spanish": "es_XX",
    "Estonian": "et_EE",
    "Finnish": "fi_FI",
    "French": "fr_XX",
    "Gujarati": "gu_IN",
    "Hindi": "hi_IN",
    "Italian": "it_IT",
    "Japanese": "ja_XX",
    "Kazakh": "kk_KZ",
    "Korean": "ko_KR",
    "Lithuanian": "lt_LT",
    "Latvian": "lv_LV",
    "Burmese": "my_MM",
    "Nepali": "ne_NP",
    "Dutch": "nl_XX",
    "Romanian": "ro_RO",
    "Russian": "ru_RU",
    "Sinhala": "si_LK",
    "Turkish": "tr_TR",
    "Vietnamese": "vi_VN",
    "Chinese": "zh_CN",
    "Afrikaans": "af_ZA",
    "Azerbaijani": "az_AZ",
    "Bengali": "bn_IN",
    "Persian": "fa_IR",
    "Hebrew": "he_IL",
    "Croatian": "hr_HR",
    "Indonesian": "id_ID",
    "Georgian": "ka_GE",
    "Khmer": "km_KH",
    "Macedonian": "mk_MK",
    "Malayalam": "ml_IN",
    "Mongolian": "mn_MN",
    "Marathi": "mr_IN",
    "Polish": "pl_PL",
    "Pashto": "ps_AF",
    "Portuguese": "pt_XX",
    "Swedish": "sv_SE",
    "Swahili": "sw_KE",
    "Tamil": "ta_IN",
    "Telugu": "te_IN",
    "Thai": "th_TH",
    "Tagalog": "tl_XX",
    "Ukrainian": "uk_UA",
    "Urdu": "ur_PK",
    "Xhosa": "xh_ZA",
    "Galician": "gl_ES",
    "Slovene": "sl_SI"
}

# %%
language=input("Enter your language name:")
for key,value in languages_dict.items():
  if key.casefold()==language.casefold():
    final_language=value
    break
# Out:
# Enter your language name:urdu

# %%
final_language
# Out:
# 'ur_PK'

# %%
generated_tokens = model.generate(
    **model_inputs,
    forced_bos_token_id=tokenizer.lang_code_to_id[final_language]
)

# %%
translation = tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)

# %%
translation
# Out:
# ['پنبه']
